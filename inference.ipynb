# %%
### Inference on a single image
import os
import json
import torch
import torch.nn as nn
from torchvision.models import EfficientNet_V2_S_Weights, efficientnet_v2_s
from PIL import Image

# --- Configuration ---
MODEL_PATH = 'models/best_model.pth'
# IMAGE_PATH = r'dataset\images\test\Hummus\18.jpg'  # <<<--- Change this to your image file
IMAGE_PATH = r"Test_data/Balaleet/train_29.jpg"
MAPPING_JSON_PATH = 'class_mapping.json'
NUM_CLASSES = 66

# --- Device Setup ---
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {DEVICE}")

# --- Load Class Mapping ---
print(f"Loading class mapping from: {MAPPING_JSON_PATH}")
try:
    with open(MAPPING_JSON_PATH, 'r') as f:
        class_to_idx = json.load(f)
    idx_to_class = {v: k for k, v in class_to_idx.items()}
    if len(idx_to_class) != NUM_CLASSES:
        print(f"Warning: Found {len(idx_to_class)} classes, expected {NUM_CLASSES}")
except Exception as e:
    raise RuntimeError(f"Failed to load class mapping: {e}")

# --- Load Model ---
print("Loading model...")
weights = EfficientNet_V2_S_Weights.IMAGENET1K_V1
model = efficientnet_v2_s(weights=weights)
num_ftrs = model.classifier[1].in_features
model.classifier[1] = nn.Sequential(
    nn.Dropout(p=0.37, inplace=True), # Keep dropout
    nn.Linear(num_ftrs, NUM_CLASSES),
)
model.load_state_dict(torch.load(MODEL_PATH, map_location=DEVICE))
model.to(DEVICE)
model.eval()

# --- Preprocessing ---
preprocess = weights.transforms()

# --- Prediction Function ---
def predict_image(image_path):
    try:
        img = Image.open(image_path).convert('RGB')
        input_tensor = preprocess(img).unsqueeze(0).to(DEVICE)
        with torch.no_grad():
            output = model(input_tensor)
            conf, idx = torch.max(torch.softmax(output, dim=1), 1)
        return idx_to_class.get(idx.item(), "Unknown"), conf.item()
    except Exception as e:
        print(f"Prediction error: {e}")
        return None, None

# --- Inference ---
if not os.path.exists(IMAGE_PATH):
    print(f"Image path does not exist: {IMAGE_PATH}")
else:
    print(f"Predicting image: {IMAGE_PATH}")
    label, confidence = predict_image(IMAGE_PATH)
    if label:
        print(f"-> Predicted Class: {label}")
        print(f"-> Confidence: {confidence:.4f}")
# Out:
# Using device: cpu
# Loading class mapping from: class_mapping.json
# Loading model...
# Predicting image: Test_data/Balaleet/train_29.jpg
# -> Predicted Class: Balaleet
# -> Confidence: 0.9967

# %%
import os
import json
import csv
import torch
import torch.nn as nn
from PIL import Image
from pathlib import Path
from torchvision.models import EfficientNet_V2_S_Weights, efficientnet_v2_s

# --- Configuration ---
MODEL_PATH = 'models/best_model.pth'
MAPPING_JSON_PATH = 'class_mapping.json'
NUM_CLASSES = 66
TEST_ROOT_DIR = 'Test_data'  # Root directory with subfolders of class names

# --- Device Setup ---
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {DEVICE}")

# --- Load Class Mapping ---
print(f"Loading class mapping from: {MAPPING_JSON_PATH}")
try:
    with open(MAPPING_JSON_PATH, 'r') as f:
        class_to_idx = json.load(f)
    idx_to_class = {v: k for k, v in class_to_idx.items()}
    if len(idx_to_class) != NUM_CLASSES:
        print(f"Warning: Found {len(idx_to_class)} classes, expected {NUM_CLASSES}")
except Exception as e:
    raise RuntimeError(f"Failed to load class mapping: {e}")

# --- Load Model ---
print("Loading model...")
weights = EfficientNet_V2_S_Weights.IMAGENET1K_V1
model = efficientnet_v2_s(weights=weights)
num_ftrs = model.classifier[1].in_features
model.classifier[1] = nn.Sequential(
    nn.Dropout(p=0.37, inplace=True),
    nn.Linear(num_ftrs, NUM_CLASSES),
)
model.load_state_dict(torch.load(MODEL_PATH, map_location=DEVICE))
model.to(DEVICE)
model.eval()

# --- Preprocessing ---
preprocess = weights.transforms()

# --- Prediction Function ---
def predict_image(image_path):
    try:
        img = Image.open(image_path).convert('RGB')
        input_tensor = preprocess(img).unsqueeze(0).to(DEVICE)
        with torch.no_grad():
            output = model(input_tensor)
            conf, idx = torch.max(torch.softmax(output, dim=1), 1)
        return idx_to_class.get(idx.item(), "Unknown"), conf.item()
    except Exception as e:
        print(f"Prediction error for {image_path}: {e}")
        return None, None

# --- Gather All Images ---
def get_all_image_paths(root_dir):
    return list(Path(root_dir).rglob("*.jpg")) + \
           list(Path(root_dir).rglob("*.jpeg")) + \
           list(Path(root_dir).rglob("*.png"))

all_images = get_all_image_paths(TEST_ROOT_DIR)

# --- Run Inference ---
if not all_images:
    print(f"No images found in: {TEST_ROOT_DIR}")
else:
    print(f"Found {len(all_images)} images. Running inference...\n")

    results = []
    for image_path in all_images:
        label, confidence = predict_image(str(image_path))
        results.append((str(image_path), label, confidence))
        print(f"Image: {image_path}")
        print(f"-> Predicted Class: {label}")
        print(f"-> Confidence: {confidence:.4f}\n")

    # --- Save Results to CSV ---
    output_csv = "predictions.csv"
    with open(output_csv, "w", newline='', encoding='utf-8') as f:
        writer = csv.writer(f)
        writer.writerow(["Image Path", "Predicted Class", "Confidence"])
        writer.writerows(results)

    print(f"Predictions saved to: {output_csv}")
# Out:
# Using device: cpu
# Loading class mapping from: class_mapping.json
# Loading model...
# Found 269 images. Running inference...
#
# Image: Test_data/Shrimp/train_74.jpg
# -> Predicted Class: Shrimp
# -> Confidence: 0.9969
#
# Image: Test_data/Shrimp/train_65.jpg
# -> Predicted Class: Shrimp
# -> Confidence: 0.9907
#
# Image: Test_data/Shrimp/train_104.jpg
# -> Predicted Class: Shrimp
# -> Confidence: 0.9850
#
# Image: Test_data/Shrimp/train_103.jpg
# -> Predicted Class: Shrimp
# -> Confidence: 0.9760
#
# Image: Test_data/Orange (fruit)/train_20.jpg
# -> Predicted Class: Orange (fruit)
# -> Confidence: 0.9954
#
# Image: Test_data/Orange (fruit)/test_652acb4266a31500.jpg
# -> Predicted Class: Orange (fruit)
# -> Confidence: 0.7617
#
# Image: Test_data/Orange (fruit)/train_70.jpg
# -> Predicted Class: Orange (fruit)
# -> Confidence: 0.9807
#
# Image: Test_data/Orange (fruit)/test_0697d514e448855d.jpg
# -> Predicted Class: Orange (fruit)
# -> Confidence: 0.9928
#
# Image: Test_data/Pomegranate/train_72.jpg
# -> Predicted Class: Pomegranate
# -> Confidence: 0.9809
#
# Image: Test_data/Pomegranate/train_24.jpg
# -> Predicted Class: Pomegranate
# -> Confidence: 0.9878
#
# Image: Test_data/Pomegranate/train_21.jpg
# -> Predicted Class: Pomegranate
# -> Confidence: 0.9871
#
# Image: Test_data/Pomegranate/test_6348dc533bd86985.jpg
# -> Predicted Class: Pomegranate
# -> Confidence: 0.9906
#
# Image: Test_data/Tahini/train_69.jpg
# -> Predicted Class: Tahini
# -> Confidence: 0.9800
#
# Image: Test_data/Tahini/train_1.jpg
# -> Predicted Class: Tahini
# -> Confidence: 0.9928
#
# Image: Test_data/Tahini/train_77.jpg
# -> Predicted Class: Tahini
# -> Confidence: 0.9626
#
# Image: Test_data/Tahini/train_68.jpg
# -> Predicted Class: Tahini
# -> Confidence: 0.9648
#
# Image: Test_data/Tahini/train_3.jpg
# -> Predicted Class: Tahini
# -> Confidence: 0.9835
#
# Image: Test_data/Cucumber/train_30.jpg
# -> Predicted Class: Cucumber
# -> Confidence: 0.9907
#
# Image: Test_data/Cucumber/train_31.jpg
# -> Predicted Class: Cucumber
# -> Confidence: 0.9973
#
# Image: Test_data/Cucumber/train_52.jpg
# -> Predicted Class: Cucumber
# -> Confidence: 0.9978
#
# Image: Test_data/Carrot/train_44.jpg
# -> Predicted Class: Carrot
# -> Confidence: 0.9945
#
# Image: Test_data/Carrot/val_0b5ab3924ef1fc74.jpg
# -> Predicted Class: Carrot
# -> Confidence: 0.9387
#
# Image: Test_data/Carrot/train_141.jpg
# -> Predicted Class: Carrot
# -> Confidence: 0.9945
#
# Image: Test_data/Kubba/test_49.jpg
# -> Predicted Class: Kubba
# -> Confidence: 0.9848
#
# Image: Test_data/Kubba/train_33.jpg
# -> Predicted Class: Kubba
# -> Confidence: 0.9800
#
# Image: Test_data/Kubba/train_77.jpg
# -> Predicted Class: Kubba
# -> Confidence: 0.9901
#
# Image: Test_data/Kubba/train_11.jpg
# -> Predicted Class: Kubba
# -> Confidence: 0.9789
#
# Image: Test_data/Kubba/val_2.jpg
# -> Predicted Class: Kubba
# -> Confidence: 0.9766
#
# Image: Test_data/Plain_white_rice/test_25.jpg
# -> Predicted Class: Plain_white_rice
# -> Confidence: 0.9960
#
# Image: Test_data/Plain_white_rice/train_44.jpg
# -> Predicted Class: Plain_white_rice
# -> Confidence: 0.9956
#
# Image: Test_data/Plain_white_rice/train_52.jpg
# -> Predicted Class: Plain_white_rice
# -> Confidence: 0.9946
#
# Image: Test_data/Plain_white_rice/train_94.jpg
# -> Predicted Class: Plain_white_rice
# -> Confidence: 0.9962
#
# Image: Test_data/Lobster/train_133.jpg
# -> Predicted Class: Lobster
# -> Confidence: 0.9763
#
# Image: Test_data/Lobster/train_95.jpg
# -> Predicted Class: Lobster
# -> Confidence: 0.9826
#
# Image: Test_data/Lobster/train_7.jpg
# -> Predicted Class: Lobster
# -> Confidence: 0.9805
#
# Image: Test_data/Lobster/train_48.jpg
# -> Predicted Class: Lobster
# -> Confidence: 0.9722
#
# Image: Test_data/Apple/train_92.jpg
# -> Predicted Class: Apple
# -> Confidence: 0.8671
#
# Image: Test_data/Apple/train_7.jpg
# -> Predicted Class: Apple
# -> Confidence: 0.9881
#
# Image: Test_data/Apple/train_54.jpg
# -> Predicted Class: Apple
# -> Confidence: 0.9473
#
# Image: Test_data/Balaleet/train_29.jpg
# -> Predicted Class: Balaleet
# -> Confidence: 0.9967
#
# Image: Test_data/Balaleet/train_36.jpg
# -> Predicted Class: Balaleet
# -> Confidence: 0.9930
#
# Image: Test_data/Balaleet/train_16.jpg
# -> Predicted Class: Balaleet
# -> Confidence: 0.9928
#
# Image: Test_data/Balaleet/train_47.jpg
# -> Predicted Class: Balaleet
# -> Confidence: 0.9825
#
# Image: Test_data/om_ali/train_42.jpg
# -> Predicted Class: om_ali
# -> Confidence: 0.9968
#
# Image: Test_data/om_ali/train_8.jpg
# -> Predicted Class: om_ali
# -> Confidence: 0.9900
#
# Image: Test_data/om_ali/test_13.jpg
# -> Predicted Class: om_ali
# -> Confidence: 0.9985
#
# Image: Test_data/om_ali/test_20.jpg
# -> Predicted Class: om_ali
# -> Confidence: 0.9454
#
# Image: Test_data/Red_tea_with_mint_or_saffron/train_1.jpg
# -> Predicted Class: Red_tea_with_mint_or_saffron
# -> Confidence: 0.9329
#
# Image: Test_data/Red_tea_with_mint_or_saffron/test_49.jpg
# -> Predicted Class: Red_tea_with_mint_or_saffron
# -> Confidence: 0.9861
#
# Image: Test_data/Red_tea_with_mint_or_saffron/train_39.jpg
# -> Predicted Class: Red_tea_with_mint_or_saffron
# -> Confidence: 0.6667
#
# Image: Test_data/Grape/test_3da0117c3a40b5c5.jpg
# -> Predicted Class: Grape
# -> Confidence: 0.9942
#
# Image: Test_data/Grape/train_110.jpg
# -> Predicted Class: Grape
# -> Confidence: 0.9904
#
# Image: Test_data/Grape/train_12.jpg
# -> Predicted Class: Grape
# -> Confidence: 0.9899
#
# Image: Test_data/Grape/train_99.jpg
# -> Predicted Class: Grape
# -> Confidence: 0.9868
#
# Image: Test_data/Grape/train_45.jpg
# -> Predicted Class: Grape
# -> Confidence: 0.9963
#
# Image: Test_data/Bell pepper/train_66.jpg
# -> Predicted Class: Bell pepper
# -> Confidence: 0.9956
#
# Image: Test_data/Bell pepper/test_5a08bb98357c5deb.jpg
# -> Predicted Class: Bell pepper
# -> Confidence: 0.9957
#
# Image: Test_data/Bell pepper/test_a454c49cdca6ea15.jpg
# -> Predicted Class: Bell pepper
# -> Confidence: 0.9967
#
# Image: Test_data/Warak_Enab/test_32.jpg
# -> Predicted Class: Warak_Enab
# -> Confidence: 0.9822
#
# Image: Test_data/Warak_Enab/train_28.jpg
# -> Predicted Class: Warak_Enab
# -> Confidence: 0.9904
#
# Image: Test_data/Warak_Enab/train_96.jpg
# -> Predicted Class: Warak_Enab
# -> Confidence: 0.9836
#
# Image: Test_data/Warak_Enab/val_11.jpg
# -> Predicted Class: Warak_Enab
# -> Confidence: 0.9645
#
# Image: Test_data/Molokhia/train_69.jpg
# -> Predicted Class: Molokhia
# -> Confidence: 0.9837
#
# Image: Test_data/Molokhia/train_74.jpg
# -> Predicted Class: Molokhia
# -> Confidence: 0.9857
#
# Image: Test_data/Molokhia/train_80.jpg
# -> Predicted Class: Molokhia
# -> Confidence: 0.9690
#
# Image: Test_data/Dajaj_Mahshi/train_16.jpg
# -> Predicted Class: Dajaj_Mahshi
# -> Confidence: 0.8230
#
# Image: Test_data/Dajaj_Mahshi/train_32.jpg
# -> Predicted Class: Dajaj_Mahshi
# -> Confidence: 0.8801
#
# Image: Test_data/Dajaj_Mahshi/train_4.jpg
# -> Predicted Class: Dajaj_Mahshi
# -> Confidence: 0.7678
#
# Image: Test_data/Dates_with_tahini/train_20.jpg
# -> Predicted Class: Dates_with_tahini
# -> Confidence: 0.9967
#
# Image: Test_data/Dates_with_tahini/train_26.jpg
# -> Predicted Class: Dates_with_tahini
# -> Confidence: 0.9972
#
# Image: Test_data/Dates_with_tahini/train_27.jpg
# -> Predicted Class: Dates_with_tahini
# -> Confidence: 0.9927
#
# Image: Test_data/Dates_with_tahini/train_43.jpg
# -> Predicted Class: Dates_with_tahini
# -> Confidence: 0.9974
#
# Image: Test_data/Dates_with_tahini/train_17.jpg
# -> Predicted Class: Dates_with_tahini
# -> Confidence: 0.9863
#
# Image: Test_data/Lentil_soup/train_135.jpg
# -> Predicted Class: Lentil_soup
# -> Confidence: 0.6550
#
# Image: Test_data/Lentil_soup/train_86.jpg
# -> Predicted Class: Lentil_soup
# -> Confidence: 0.8750
#
# Image: Test_data/Lentil_soup/val_123.jpg
# -> Predicted Class: Lentil_soup
# -> Confidence: 0.9589
#
# Image: Test_data/Lentil_soup/train_56.jpg
# -> Predicted Class: Lentil_soup
# -> Confidence: 0.9143
#
# Image: Test_data/khabeesa/train_23.jpg
# -> Predicted Class: khabeesa
# -> Confidence: 0.8383
#
# Image: Test_data/Basbousa/train_125.jpg
# -> Predicted Class: Basbousa
# -> Confidence: 0.9888
#
# Image: Test_data/Basbousa/test_90.jpg
# -> Predicted Class: Basbousa
# -> Confidence: 0.9925
#
# Image: Test_data/Basbousa/train_19.jpg
# -> Predicted Class: Basbousa
# -> Confidence: 0.9966
#
# Image: Test_data/Basbousa/val_12.jpg
# -> Predicted Class: Basbousa
# -> Confidence: 0.9825
#
# Image: Test_data/Tamarind_juice/train_8.jpg
# -> Predicted Class: Tamarind_juice
# -> Confidence: 0.9974
#
# Image: Test_data/Tamarind_juice/test_19.jpg
# -> Predicted Class: Tamarind_juice
# -> Confidence: 0.9930
#
# Image: Test_data/Tamarind_juice/train_43.jpg
# -> Predicted Class: Tamarind_juice
# -> Confidence: 0.9990
#
# Image: Test_data/Tamarind_juice/train_58.jpg
# -> Predicted Class: Tamarind_juice
# -> Confidence: 0.7850
#
# Image: Test_data/Muhammara/val_18.jpg
# -> Predicted Class: Muhammara
# -> Confidence: 0.8243
#
# Image: Test_data/Muhammara/val_16.jpg
# -> Predicted Class: Muhammara
# -> Confidence: 0.9229
#
# Image: Test_data/Muhammara/test_83.jpg
# -> Predicted Class: Muhammara
# -> Confidence: 0.9777
#
# Image: Test_data/Muhammara/train_75.jpg
# -> Predicted Class: Muhammara
# -> Confidence: 0.9911
#
# Image: Test_data/Muhammara/train_12.jpg
# -> Predicted Class: Muhammara
# -> Confidence: 0.9939
#
# Image: Test_data/Murabyan/test_38.jpg
# -> Predicted Class: Murabyan
# -> Confidence: 0.9330
#
# Image: Test_data/Murabyan/test_24.jpg
# -> Predicted Class: Murabyan
# -> Confidence: 0.8533
#
# Image: Test_data/Murabyan/train_3.jpg
# -> Predicted Class: Murabyan
# -> Confidence: 0.7032
#
# Image: Test_data/Fattoush/train_8.jpg
# -> Predicted Class: Fattoush
# -> Confidence: 0.9841
#
# Image: Test_data/Fattoush/test_19.jpg
# -> Predicted Class: Fattoush
# -> Confidence: 0.9967
#
# Image: Test_data/Fattoush/train_24.jpg
# -> Predicted Class: Fattoush
# -> Confidence: 0.9968
#
# Image: Test_data/Fattoush/train_56.jpg
# -> Predicted Class: Fattoush
# -> Confidence: 0.9969
#
# Image: Test_data/Tea_with_milk/train_74.jpg
# -> Predicted Class: Tea_with_milk
# -> Confidence: 0.9893
#
# Image: Test_data/Tea_with_milk/train_73.jpg
# -> Predicted Class: Tea_with_milk
# -> Confidence: 0.9927
#
# Image: Test_data/Tea_with_milk/train_185.jpg
# -> Predicted Class: Tea_with_milk
# -> Confidence: 0.9939
#
# Image: Test_data/Oyster/train_73.jpg
# -> Predicted Class: Oyster
# -> Confidence: 0.9870
#
# Image: Test_data/Oyster/train_46.jpg
# -> Predicted Class: Oyster
# -> Confidence: 0.9932
#
# Image: Test_data/Oyster/train_110.jpg
# -> Predicted Class: Oyster
# -> Confidence: 0.9901
#
# Image: Test_data/Oyster/train_58.jpg
# -> Predicted Class: Oyster
# -> Confidence: 0.9937
#
# Image: Test_data/Oyster/train_48.jpg
# -> Predicted Class: Oyster
# -> Confidence: 0.9919
#
# Image: Test_data/Tamria(Tamriyeh)/val_49.jpg
# -> Predicted Class: Tamria(Tamriyeh)
# -> Confidence: 0.9916
#
# Image: Test_data/Tamria(Tamriyeh)/train_44.jpg
# -> Predicted Class: Tamria(Tamriyeh)
# -> Confidence: 0.8709
#
# Image: Test_data/Tamria(Tamriyeh)/train_50.jpg
# -> Predicted Class: Tamria(Tamriyeh)
# -> Confidence: 0.9746
#
# Image: Test_data/Tamria(Tamriyeh)/train_6.jpg
# -> Predicted Class: Tamria(Tamriyeh)
# -> Confidence: 0.9264
#
# Image: Test_data/Tamria(Tamriyeh)/train_19.jpg
# -> Predicted Class: Tamria(Tamriyeh)
# -> Confidence: 0.9278
#
# Image: Test_data/laban_drink/train_59.jpg
# -> Predicted Class: laban_drink
# -> Confidence: 0.9902
#
# Image: Test_data/laban_drink/train_7.jpg
# -> Predicted Class: laban_drink
# -> Confidence: 0.9893
#
# Image: Test_data/laban_drink/train_56.jpg
# -> Predicted Class: laban_drink
# -> Confidence: 0.9901
#
# Image: Test_data/laban_drink/train_49.jpg
# -> Predicted Class: laban_drink
# -> Confidence: 0.9928
#
# Image: Test_data/laban_drink/train_47.jpg
# -> Predicted Class: laban_drink
# -> Confidence: 0.9896
#
# Image: Test_data/Musakhan_Chicken/train_93.jpg
# -> Predicted Class: Musakhan_Chicken
# -> Confidence: 0.9496
#
# Image: Test_data/Musakhan_Chicken/train_79.jpg
# -> Predicted Class: Musakhan_Chicken
# -> Confidence: 0.8963
#
# Image: Test_data/Musakhan_Chicken/train_80.jpg
# -> Predicted Class: Musakhan_Chicken
# -> Confidence: 0.9639
#
# Image: Test_data/Musakhan_Chicken/val_45.jpg
# -> Predicted Class: Musakhan_Chicken
# -> Confidence: 0.9526
#
# Image: Test_data/Musakhan_Chicken/train_60.jpg
# -> Predicted Class: Musakhan_Chicken
# -> Confidence: 0.9681
#
# Image: Test_data/Radish/train_117.jpg
# -> Predicted Class: Radish
# -> Confidence: 0.9480
#
# Image: Test_data/Radish/train_67.jpg
# -> Predicted Class: Radish
# -> Confidence: 0.9923
#
# Image: Test_data/Radish/train_11.jpg
# -> Predicted Class: Radish
# -> Confidence: 0.9536
#
# Image: Test_data/Radish/train_49.jpg
# -> Predicted Class: Radish
# -> Confidence: 0.9944
#
# Image: Test_data/Gers_Ogaily/train_71.jpg
# -> Predicted Class: Gers_Ogaily
# -> Confidence: 0.9924
#
# Image: Test_data/Gers_Ogaily/train_75.jpg
# -> Predicted Class: Gers_Ogaily
# -> Confidence: 0.9961
#
# Image: Test_data/Gers_Ogaily/val_32.jpg
# -> Predicted Class: Gers_Ogaily
# -> Confidence: 0.9861
#
# Image: Test_data/Gers_Ogaily/train_47.jpg
# -> Predicted Class: Gers_Ogaily
# -> Confidence: 0.9794
#
# Image: Test_data/Kebab/train_92.jpg
# -> Predicted Class: Kebab
# -> Confidence: 0.9937
#
# Image: Test_data/Kebab/val_71.jpg
# -> Predicted Class: Kebab
# -> Confidence: 0.9915
#
# Image: Test_data/Kebab/train_19.jpg
# -> Predicted Class: Kebab
# -> Confidence: 0.9902
#
# Image: Test_data/Crab/train_1.jpg
# -> Predicted Class: Crab
# -> Confidence: 0.9887
#
# Image: Test_data/Crab/train_63.jpg
# -> Predicted Class: Crab
# -> Confidence: 0.9936
#
# Image: Test_data/Crab/train_106.jpg
# -> Predicted Class: Crab
# -> Confidence: 0.9979
#
# Image: Test_data/Crab/train_107.jpg
# -> Predicted Class: Crab
# -> Confidence: 0.9911
#
# Image: Test_data/Strawberry/train_55.jpg
# -> Predicted Class: Strawberry
# -> Confidence: 0.9929
#
# Image: Test_data/Strawberry/train_38.jpg
# -> Predicted Class: Strawberry
# -> Confidence: 0.9892
#
# Image: Test_data/Strawberry/val_1e8a39add490c98c.jpg
# -> Predicted Class: Strawberry
# -> Confidence: 0.9935
#
# Image: Test_data/Strawberry/train_12.jpg
# -> Predicted Class: Strawberry
# -> Confidence: 0.9935
#
# Image: Test_data/Strawberry/val_26204a3f7590cd5b.jpg
# -> Predicted Class: Strawberry
# -> Confidence: 0.9956
#
# Image: Test_data/rice_with_meat/train_145.jpg
# -> Predicted Class: rice_with_meat
# -> Confidence: 0.9871
#
# Image: Test_data/rice_with_meat/train_177.jpg
# -> Predicted Class: rice_with_meat
# -> Confidence: 0.9838
#
# Image: Test_data/rice_with_meat/test_122.jpg
# -> Predicted Class: rice_with_meat
# -> Confidence: 0.9505
#
# Image: Test_data/Saffron/train_30.jpg
# -> Predicted Class: Saffron
# -> Confidence: 0.9891
#
# Image: Test_data/Saffron/train_134.jpg
# -> Predicted Class: Saffron
# -> Confidence: 0.9923
#
# Image: Test_data/Saffron/train_7.jpg
# -> Predicted Class: Saffron
# -> Confidence: 0.9905
#
# Image: Test_data/Saffron/train_3.jpg
# -> Predicted Class: Saffron
# -> Confidence: 0.9874
#
# Image: Test_data/Saffron/train_53.jpg
# -> Predicted Class: Saffron
# -> Confidence: 0.9902
#
# Image: Test_data/Potato/train_55.jpg
# -> Predicted Class: Potato
# -> Confidence: 0.9866
#
# Image: Test_data/Potato/train_59.jpg
# -> Predicted Class: Potato
# -> Confidence: 0.9963
#
# Image: Test_data/Potato/test_83812a7be70c6778.jpg
# -> Predicted Class: Potato
# -> Confidence: 0.9830
#
# Image: Test_data/Pear/train_67.jpg
# -> Predicted Class: Pear
# -> Confidence: 0.9919
#
# Image: Test_data/Pear/train_33.jpg
# -> Predicted Class: Pear
# -> Confidence: 0.9682
#
# Image: Test_data/Pear/train_100.jpg
# -> Predicted Class: Pear
# -> Confidence: 0.9963
#
# Image: Test_data/Pear/train_96.jpg
# -> Predicted Class: Pear
# -> Confidence: 0.9830
#
# Image: Test_data/Labneh/train_9.jpg
# -> Predicted Class: Labneh
# -> Confidence: 0.9911
#
# Image: Test_data/Labneh/train_78.jpg
# -> Predicted Class: Labneh
# -> Confidence: 0.9945
#
# Image: Test_data/Labneh/val_38.jpg
# -> Predicted Class: Labneh
# -> Confidence: 0.9937
#
# Image: Test_data/Labneh/train_114.jpg
# -> Predicted Class: Labneh
# -> Confidence: 0.9803
#
# Image: Test_data/Pumpkin/val_db0499337b67676d.jpg
# -> Predicted Class: Pumpkin
# -> Confidence: 0.9953
#
# Image: Test_data/Pumpkin/train_12.jpg
# -> Predicted Class: Pumpkin
# -> Confidence: 0.9957
#
# Image: Test_data/Pumpkin/val_f7b2f1929fed4ce5.jpg
# -> Predicted Class: Pumpkin
# -> Confidence: 0.9710
#
# Image: Test_data/Harees/train_20.jpg
# -> Predicted Class: Harees
# -> Confidence: 0.9772
#
# Image: Test_data/Harees/train_71.jpg
# -> Predicted Class: Harees
# -> Confidence: 0.9928
#
# Image: Test_data/Harees/train_87.jpg
# -> Predicted Class: Harees
# -> Confidence: 0.9023
#
# Image: Test_data/Harees/val_45.jpg
# -> Predicted Class: Harees
# -> Confidence: 0.6643
#
# Image: Test_data/Tabouleh/train_97.jpg
# -> Predicted Class: Tabouleh
# -> Confidence: 0.9926
#
# Image: Test_data/Tabouleh/train_25.jpg
# -> Predicted Class: Tabouleh
# -> Confidence: 0.9939
#
# Image: Test_data/Tabouleh/train_76.jpg
# -> Predicted Class: Tabouleh
# -> Confidence: 0.9960
#
# Image: Test_data/Tabouleh/test_105.jpg
# -> Predicted Class: Tabouleh
# -> Confidence: 0.9918
#
# Image: Test_data/Tabouleh/train_113.jpg
# -> Predicted Class: Tabouleh
# -> Confidence: 0.9942
#
# Image: Test_data/Banana/train_30.jpg
# -> Predicted Class: Banana
# -> Confidence: 0.9682
#
# Image: Test_data/Banana/train_39.jpg
# -> Predicted Class: Banana
# -> Confidence: 0.9883
#
# Image: Test_data/Broccoli/test_d601782ca2835c8f.jpg
# -> Predicted Class: Broccoli
# -> Confidence: 0.9943
#
# Image: Test_data/Broccoli/train_80.jpg
# -> Predicted Class: Broccoli
# -> Confidence: 0.9784
#
# Image: Test_data/Broccoli/train_58.jpg
# -> Predicted Class: Broccoli
# -> Confidence: 0.9935
#
# Image: Test_data/Lentil_stew/train_20.jpg
# -> Predicted Class: Lentil_stew
# -> Confidence: 0.8432
#
# Image: Test_data/Lentil_stew/test_38.jpg
# -> Predicted Class: Lentil_stew
# -> Confidence: 0.7815
#
# Image: Test_data/Jireesh/train_9.jpg
# -> Predicted Class: Jireesh
# -> Confidence: 0.8327
#
# Image: Test_data/Jireesh/train_5.jpg
# -> Predicted Class: Jireesh
# -> Confidence: 0.8545
#
# Image: Test_data/Zaatar/train_102.jpg
# -> Predicted Class: Zaatar
# -> Confidence: 0.3928
#
# Image: Test_data/Zaatar/train_70.jpg
# -> Predicted Class: Zaatar
# -> Confidence: 0.9735
#
# Image: Test_data/Zaatar/train_88.jpg
# -> Predicted Class: Zaatar
# -> Confidence: 0.9921
#
# Image: Test_data/Zaatar/train_122.jpg
# -> Predicted Class: Zaatar
# -> Confidence: 0.9831
#
# Image: Test_data/Pineapple/val_ed00e1ad397a569e.jpg
# -> Predicted Class: Pineapple
# -> Confidence: 0.9940
#
# Image: Test_data/Pineapple/test_82aa7f6c430527d2.jpg
# -> Predicted Class: Pineapple
# -> Confidence: 0.9942
#
# Image: Test_data/Pineapple/train_96.jpg
# -> Predicted Class: Pineapple
# -> Confidence: 0.9896
#
# Image: Test_data/Pineapple/train_45.jpg
# -> Predicted Class: Pineapple
# -> Confidence: 0.9911
#
# Image: Test_data/Artichoke/test_cbce0fff8ba0866a.jpg
# -> Predicted Class: Artichoke
# -> Confidence: 0.9972
#
# Image: Test_data/Artichoke/train_61.jpg
# -> Predicted Class: Artichoke
# -> Confidence: 0.9961
#
# Image: Test_data/Artichoke/test_3dbc4215166afab8.jpg
# -> Predicted Class: Artichoke
# -> Confidence: 0.9955
#
# Image: Test_data/Artichoke/train_68.jpg
# -> Predicted Class: Artichoke
# -> Confidence: 0.9973
#
# Image: Test_data/Artichoke/train_62.jpg
# -> Predicted Class: Artichoke
# -> Confidence: 0.9986
#
# Image: Test_data/Bamya/train_109.jpg
# -> Predicted Class: Bamya
# -> Confidence: 0.9984
#
# Image: Test_data/Bamya/val_88.jpg
# -> Predicted Class: Bamya
# -> Confidence: 0.9876
#
# Image: Test_data/Bamya/train_129.jpg
# -> Predicted Class: Bamya
# -> Confidence: 0.9976
#
# Image: Test_data/Bamya/train_93.jpg
# -> Predicted Class: Bamya
# -> Confidence: 0.9985
#
# Image: Test_data/Hummus/train_20.jpg
# -> Predicted Class: Hummus
# -> Confidence: 0.8344
#
# Image: Test_data/Hummus/test_36.jpg
# -> Predicted Class: Hummus
# -> Confidence: 0.7518
#
# Image: Test_data/Hummus/train_41.jpg
# -> Predicted Class: Hummus
# -> Confidence: 0.9657
#
# Image: Test_data/bread/train_78.jpg
# -> Predicted Class: bread
# -> Confidence: 0.9945
#
# Image: Test_data/bread/train_124.jpg
# -> Predicted Class: bread
# -> Confidence: 0.9949
#
# Image: Test_data/bread/val_26.jpg
# -> Predicted Class: bread
# -> Confidence: 0.9652
#
# Image: Test_data/bread/val_53.jpg
# -> Predicted Class: bread
# -> Confidence: 0.9917
#
# Image: Test_data/Watermelon/train_83.jpg
# -> Predicted Class: Watermelon
# -> Confidence: 0.9926
#
# Image: Test_data/Watermelon/train_66.jpg
# -> Predicted Class: Watermelon
# -> Confidence: 0.9907
#
# Image: Test_data/Watermelon/train_108.jpg
# -> Predicted Class: Watermelon
# -> Confidence: 0.9882
#
# Image: Test_data/Watermelon/train_81.jpg
# -> Predicted Class: Watermelon
# -> Confidence: 0.9873
#
# Image: Test_data/Watermelon/train_123.jpg
# -> Predicted Class: Watermelon
# -> Confidence: 0.9694
#
# Image: Test_data/Luqaimat/train_42.jpg
# -> Predicted Class: Luqaimat
# -> Confidence: 0.9935
#
# Image: Test_data/Luqaimat/train_4.jpg
# -> Predicted Class: Luqaimat
# -> Confidence: 0.9898
#
# Image: Test_data/Luqaimat/train_90.jpg
# -> Predicted Class: Luqaimat
# -> Confidence: 0.9697
#
# Image: Test_data/Luqaimat/train_19.jpg
# -> Predicted Class: Luqaimat
# -> Confidence: 0.9728
#
# Image: Test_data/Modas_rice/train_69.jpg
# -> Predicted Class: Modas_rice
# -> Confidence: 0.8956
#
# Image: Test_data/Modas_rice/train_74.jpg
# -> Predicted Class: Modas_rice
# -> Confidence: 0.9753
#
# Image: Test_data/Modas_rice/train_52.jpg
# -> Predicted Class: Modas_rice
# -> Confidence: 0.7370
#
# Image: Test_data/Modas_rice/val_31.jpg
# -> Predicted Class: Modas_rice
# -> Confidence: 0.9792
#
# Image: Test_data/Mallooba(Maqluba)/train_29.jpg
# -> Predicted Class: Mallooba(Maqluba)
# -> Confidence: 0.9837
#
# Image: Test_data/Mallooba(Maqluba)/test_91.jpg
# -> Predicted Class: Mallooba(Maqluba)
# -> Confidence: 0.7651
#
# Image: Test_data/Mallooba(Maqluba)/train_76.jpg
# -> Predicted Class: Mallooba(Maqluba)
# -> Confidence: 0.9751
#
# Image: Test_data/Mallooba(Maqluba)/train_41.jpg
# -> Predicted Class: Mallooba(Maqluba)
# -> Confidence: 0.9978
#
# Image: Test_data/Samosa/train_117.jpg
# -> Predicted Class: Samosa
# -> Confidence: 0.9816
#
# Image: Test_data/Samosa/train_79.jpg
# -> Predicted Class: Samosa
# -> Confidence: 0.9708
#
# Image: Test_data/Samosa/train_35.jpg
# -> Predicted Class: Samosa
# -> Confidence: 0.9872
#
# Image: Test_data/Samosa/train_76.jpg
# -> Predicted Class: Samosa
# -> Confidence: 0.9879
#
# Image: Test_data/Samosa/train_101.jpg
# -> Predicted Class: Samosa
# -> Confidence: 0.9879
#
# Image: Test_data/Peach/test_c67690652c6d050b.jpg
# -> Predicted Class: Peach
# -> Confidence: 0.9393
#
# Image: Test_data/Peach/train_51.jpg
# -> Predicted Class: Peach
# -> Confidence: 0.9719
#
# Image: Test_data/Peach/test_91b688aa180b66c2.jpg
# -> Predicted Class: Peach
# -> Confidence: 0.7932
#
# Image: Test_data/Peach/test_f8195c9d7f437f71.jpg
# -> Predicted Class: Peach
# -> Confidence: 0.6412
#
# Image: Test_data/Peach/train_81.jpg
# -> Predicted Class: Peach
# -> Confidence: 0.9243
#
# Image: Test_data/Plain_white_rice/train_54.jpeg
# -> Predicted Class: Plain_white_rice
# -> Confidence: 0.9980
#
# Image: Test_data/Fries/val_Fries-Valid (346).jpeg
# -> Predicted Class: Fries
# -> Confidence: 0.9060
#
# Image: Test_data/Fries/train_Fries-Train (984).jpeg
# -> Predicted Class: Fries
# -> Confidence: 0.9910
#
# Image: Test_data/Fries/test_Fries-Test (64).jpeg
# -> Predicted Class: Fries
# -> Confidence: 0.9845
#
# Image: Test_data/Fries/train_Fries-Train (755).jpeg
# -> Predicted Class: Fries
# -> Confidence: 0.9951
#
# Image: Test_data/Fries/train_Fries-Train (933).jpeg
# -> Predicted Class: Fries
# -> Confidence: 0.9902
#
# Image: Test_data/om_ali/train_84.jpeg
# -> Predicted Class: om_ali
# -> Confidence: 0.9991
#
# Image: Test_data/Red_tea_with_mint_or_saffron/val_61.jpeg
# -> Predicted Class: Red_tea_with_mint_or_saffron
# -> Confidence: 0.9866
#
# Image: Test_data/khabeesa/train_21.jpeg
# -> Predicted Class: khabeesa
# -> Confidence: 0.7505
#
# Image: Test_data/Basbousa/train_68.jpeg
# -> Predicted Class: Basbousa
# -> Confidence: 0.9861
#
# Image: Test_data/Pizza/train_Pizza-Train (656).jpeg
# -> Predicted Class: Pizza
# -> Confidence: 0.9925
#
# Image: Test_data/Pizza/train_Pizza-Train (708).jpeg
# -> Predicted Class: Pizza
# -> Confidence: 0.9892
#
# Image: Test_data/Pizza/train_Pizza-Train (666).jpeg
# -> Predicted Class: Pizza
# -> Confidence: 0.9831
#
# Image: Test_data/Pizza/train_Pizza-Train (803).jpeg
# -> Predicted Class: Pizza
# -> Confidence: 0.9927
#
# Image: Test_data/Gers_Ogaily/train_50.jpeg
# -> Predicted Class: Gers_Ogaily
# -> Confidence: 0.9835
#
# Image: Test_data/rice_with_meat/val_174.jpeg
# -> Predicted Class: rice_with_meat
# -> Confidence: 0.8238
#
# Image: Test_data/Sandwich/train_Sandwich-Train (1155).jpeg
# -> Predicted Class: Sandwich
# -> Confidence: 0.9687
#
# Image: Test_data/Sandwich/train_Sandwich-Train (1481).jpeg
# -> Predicted Class: Sandwich
# -> Confidence: 0.9885
#
# Image: Test_data/Sandwich/train_Sandwich-Train (1115).jpeg
# -> Predicted Class: Sandwich
# -> Confidence: 0.9947
#
# Image: Test_data/Burger/train_Burger-Train (141).jpeg
# -> Predicted Class: Burger
# -> Confidence: 0.9860
#
# Image: Test_data/Burger/train_Burger-Train (1446).jpeg
# -> Predicted Class: Burger
# -> Confidence: 0.9810
#
# Image: Test_data/Burger/test_Burger-Test (20).jpeg
# -> Predicted Class: Burger
# -> Confidence: 0.9750
#
# Image: Test_data/Burger/train_Burger-Train (761).jpeg
# -> Predicted Class: Burger
# -> Confidence: 0.9068
#
# Image: Test_data/Burger/train_Burger-Train (1033).jpeg
# -> Predicted Class: Burger
# -> Confidence: 0.8724
#
# Image: Test_data/Bamya/train_164.jpeg
# -> Predicted Class: Bamya
# -> Confidence: 0.9976
#
# Image: Test_data/Taco/train_Taco-Train (1126).jpeg
# -> Predicted Class: Taco
# -> Confidence: 0.9847
#
# Image: Test_data/Taco/train_Taco-Train (1095).jpeg
# -> Predicted Class: Taco
# -> Confidence: 0.9948
#
# Image: Test_data/Taco/val_Taco-Valid (360).jpeg
# -> Predicted Class: Taco
# -> Confidence: 0.9963
#
# Image: Test_data/Taco/train_Taco-Train (795).jpeg
# -> Predicted Class: Taco
# -> Confidence: 0.9927
#
# Image: Test_data/Red_tea_with_mint_or_saffron/train_65.png
# -> Predicted Class: Red_tea_with_mint_or_saffron
# -> Confidence: 0.9803
#
# Image: Test_data/Tamarind_juice/train_90.png
# -> Predicted Class: Tamarind_juice
# -> Confidence: 0.9920
#
# Image: Test_data/Kebab/train_18.png
# -> Predicted Class: Kebab
# -> Confidence: 0.9954
#
# Image: Test_data/rice_with_meat/train_105.png
# -> Predicted Class: rice_with_meat
# -> Confidence: 0.9179
#
# Image: Test_data/Labneh/train_18.png
# -> Predicted Class: Labneh
# -> Confidence: 0.9878
#
# Image: Test_data/Harees/train_22.png
# -> Predicted Class: Harees
# -> Confidence: 0.9329
#
# Image: Test_data/Luqaimat/train_49.png
# -> Predicted Class: Luqaimat
# -> Confidence: 0.9880
#
# Image: Test_data/Modas_rice/train_91.png
# -> Predicted Class: Modas_rice
# -> Confidence: 0.9522
#
# Predictions saved to: predictions.csv
